# %%
import os
os.chdir('../exp2')

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn
import numpy as np

# %%
data = joblib.load('results.pkl')

# %%
mean_ls = np.array([np.mean([r['rewards'].sum() for r in x])for x in data])
std_ls = np.array([np.std([r['rewards'].sum() for r in x])for x in data])

# %%
x = list(range(1, 300, 3))
plt.plot(x, mean_ls, label = 'Average total rewards')
plt.fill_between(x,mean_ls-std_ls, mean_ls+std_ls, alpha = 0.3)
# plt.legend()
plt.xlabel('Episode #')
plt.ylabel('Average total rewards')
plt.savefig('/Users/zhiyuanyao/Desktop/fig1.png')

# %%
mean_ls_2[-10:]
# Out:
# array([3688.91892123, 3630.22720895, 3648.40559087, 3561.54086539,
#        3623.99447551, 3617.63954087, 3661.09992247, 3660.57819592,
#        3646.77646357, 3656.46092555])

# %%
os.chdir('../exp3')

# %%
data = joblib.load('results.pkl')
mean_ls_2 = np.array([np.mean([r['rewards'].sum() for r in x])for x in data])
std_ls_2 = np.array([np.std([r['rewards'].sum() for r in x])for x in data])

# %%
x = list(range(1, 270, 3))
plt.plot(x, mean_ls[:len(x)], label = 'Exp. 1')
plt.fill_between(x,(mean_ls-std_ls)[:len(x)], (mean_ls+std_ls)[:len(x)], alpha = 0.3)
plt.plot(x, mean_ls_2:len(x)],  color = 'red', label = 'Exp. 2')
plt.fill_between(x,(mean_ls_2-std_ls_2)[:len(x)], (mean_ls_2+std_ls_2)[:len(x)], alpha = 0.3, color = 'red')
plt.legend()
plt.xlabel('Iteration #')
plt.ylabel('Average total rewards')
plt.savefig('/Users/zhiyuanyao/Desktop/fig1.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-644cae514e28> in <module>
#       1 x = list(range(1, 270, 3))
# ----> 2 plt.plot(x, mean_ls, label = 'Exp. 1')
#       3 plt.fill_between(x,mean_ls-std_ls, mean_ls+std_ls, alpha = 0.3)
#       4 plt.plot(x, mean_ls_2,  color = 'red', label = 'Exp. 2')
#       5 plt.fill_between(x,mean_ls_2-std_ls_2, mean_ls_2+std_ls_2, alpha = 0.3, color = 'red')
#
# ~/miniconda3/envs/gym/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~/miniconda3/envs/gym/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
# ...

# %%
mean_ls.max()
# Out:
# 3443.2415142287928
